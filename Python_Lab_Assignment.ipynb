# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\\$645 - 675) underperformed compared to schools with smaller budgets (\\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %% [markdown]
# **Note:**
# Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "schools_complete.csv"
student_data_to_load = "students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()

# school_data_complete.count()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Total number of schools
numschool = len(pd.unique(school_data_complete['school_name']))
numschool
# Out:
# 15

# %%
# Total number of students
kids = len(pd.unique(school_data_complete['Student ID']))
kids
# Out:
# 39170

# %%
# Total budget
unique_school = pd.unique(school_data_complete['budget'])
budget = sum(unique_school)
budget
# Out:
# 24649428

# %%
# Average math score
m=np.mean(school_data_complete.math_score)
m
# Out:
# 78.98537145774827

# %%
# Average reading score
r=np.mean(school_data_complete.reading_score)
r
# Out:
# 81.87784018381414

# %%
# Overall average score
overall = (m+r)/2
overall
# Out:
# 80.43160582078121

# %%
# Percentage of passing math (70 or greater)
count = 0
for i in school_data_complete.math_score:
    if i > 70:
        count = count + 1
        
passingm = (count/kids)*100
passingm
# Out:
# 72.39213683941792

# %%
# Percentage of passing reading (70 or greater)
count = 0
for i in school_data_complete.reading_score:
    if i > 70:
        count = count + 1
        
passingr = (count/kids)*100
passingr
# Out:
# 82.97166198621395

# %%
results = {'# of. schools': [numschool],
           '# of sstudents': [kids], 
           'budget': [budget], 
           'avg. math': [m],
           'avg. read': [r],
           'overall avg': [overall], 
           'pass math': [passingm], 
           'pass read': [passingr]}
resultsdf = pd.DataFrame(results)
resultsdf
# Out:
#    # of. schools  # of sstudents    budget  avg. math  avg. read  overall avg  \
# 0             15           39170  24649428  78.985371   81.87784    80.431606
#
#    pass math  pass read
# 0  72.392137  82.971662

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ### Top Performing Schools (By Passing Rate)

# %%
# Calculate total school budget
school_data_complete.loc[:,['school_name', 'budget']].drop_duplicates()
# Out:
#                  school_name   budget
# 0          Huang High School  1910635
# 2917    Figueroa High School  1884411
# 5866     Shelton High School  1056600
# 7627   Hernandez High School  3022020
# 12262    Griffin High School   917500
# 13730     Wilson High School  1319574
# 16013    Cabrera High School  1081356
# 17871     Bailey High School  3124928
# 22847     Holden High School   248087
# 23274       Pena High School   585858
# 24236     Wright High School  1049400
# 26036  Rodriguez High School  2547363
# 30035    Johnson High School  3094650
# 34796       Ford High School  1763916
# 37535     Thomas High School  1043130

# %%
# Calculate per student budget
school_data_complete['per student budget'] = school_data_complete['budget'] / school_data_complete['size']
school_data_complete.loc[:,['school_name', 'per student budget']].drop_duplicates()
# Out:
#                  school_name  per student budget
# 0          Huang High School               655.0
# 2917    Figueroa High School               639.0
# 5866     Shelton High School               600.0
# 7627   Hernandez High School               652.0
# 12262    Griffin High School               625.0
# 13730     Wilson High School               578.0
# 16013    Cabrera High School               582.0
# 17871     Bailey High School               628.0
# 22847     Holden High School               581.0
# 23274       Pena High School               609.0
# 24236     Wright High School               583.0
# 26036  Rodriguez High School               637.0
# 30035    Johnson High School               650.0
# 34796       Ford High School               644.0
# 37535     Thomas High School               638.0

# %%
# Cacluate the avg math and reading score
rmdata = school_data_complete.loc[:,['school_name', 'math_score', 'reading_score']]
scores = rmdata.groupby('school_name').mean()
scores
# Out:
#                        math_score  reading_score
# school_name
# Bailey High School      77.048432      81.033963
# Cabrera High School     83.061895      83.975780
# Figueroa High School    76.711767      81.158020
# Ford High School        77.102592      80.746258
# Griffin High School     83.351499      83.816757
# Hernandez High School   77.289752      80.934412
# Holden High School      83.803279      83.814988
# Huang High School       76.629414      81.182722
# Johnson High School     77.072464      80.966394
# Pena High School        83.839917      84.044699
# Rodriguez High School   76.842711      80.744686
# Shelton High School     83.359455      83.725724
# Thomas High School      83.418349      83.848930
# Wilson High School      83.274201      83.989488
# Wright High School      83.682222      83.955000

# %% [markdown]
# #### Find the passing rate for math and reading (above 70 points)

# %%
# Find the total counts of math result
math = school_data_complete.loc[:,['school_name', 'math_score']]
counts = math.groupby('school_name').count()
counts
# Out:
#                        math_score
# school_name
# Bailey High School           4976
# Cabrera High School          1858
# Figueroa High School         2949
# Ford High School             2739
# Griffin High School          1468
# Hernandez High School        4635
# Holden High School            427
# Huang High School            2917
# Johnson High School          4761
# Pena High School              962
# Rodriguez High School        3999
# Shelton High School          1761
# Thomas High School           1635
# Wilson High School           2283
# Wright High School           1800

# %%
# Find the counts for math result in each school that pass 70 or higher
countpassm = math[math['math_score'] >= 70]
countpassm = countpassm.groupby('school_name').count()
countpassm
# Out:
#                        math_score
# school_name
# Bailey High School           3318
# Cabrera High School          1749
# Figueroa High School         1946
# Ford High School             1871
# Griffin High School          1371
# Hernandez High School        3094
# Holden High School            395
# Huang High School            1916
# Johnson High School          3145
# Pena High School              910
# Rodriguez High School        2654
# Shelton High School          1653
# Thomas High School           1525
# Wilson High School           2143
# Wright High School           1680

# %%
# Calculate the math passing rate
passingratem = countpassm/counts
passingratem
# Out:
#                        math_score
# school_name
# Bailey High School       0.666801
# Cabrera High School      0.941335
# Figueroa High School     0.659885
# Ford High School         0.683096
# Griffin High School      0.933924
# Hernandez High School    0.667530
# Holden High School       0.925059
# Huang High School        0.656839
# Johnson High School      0.660576
# Pena High School         0.945946
# Rodriguez High School    0.663666
# Shelton High School      0.938671
# Thomas High School       0.932722
# Wilson High School       0.938677
# Wright High School       0.933333

# %%
# Find the total counts of read result
read = school_data_complete.loc[:,['school_name', 'reading_score']]
counts = read.groupby('school_name').count()
counts
# Out:
#                        reading_score
# school_name
# Bailey High School              4976
# Cabrera High School             1858
# Figueroa High School            2949
# Ford High School                2739
# Griffin High School             1468
# Hernandez High School           4635
# Holden High School               427
# Huang High School               2917
# Johnson High School             4761
# Pena High School                 962
# Rodriguez High School           3999
# Shelton High School             1761
# Thomas High School              1635
# Wilson High School              2283
# Wright High School              1800

# %%
# Find the counts for read result in each school that pass 70 or higher
countpassr = read[read['reading_score'] >= 70]
countpassr = countpassr.groupby('school_name').count()
countpassr
# Out:
#                        reading_score
# school_name
# Bailey High School              4077
# Cabrera High School             1803
# Figueroa High School            2381
# Ford High School                2172
# Griffin High School             1426
# Hernandez High School           3748
# Holden High School               411
# Huang High School               2372
# Johnson High School             3867
# Pena High School                 923
# Rodriguez High School           3208
# Shelton High School             1688
# Thomas High School              1591
# Wilson High School              2204
# Wright High School              1739

# %%
# Calculate the read passing rate
passingrater = countpassr/counts
passingrater
# Out:
#                        reading_score
# school_name
# Bailey High School          0.819333
# Cabrera High School         0.970398
# Figueroa High School        0.807392
# Ford High School            0.792990
# Griffin High School         0.971390
# Hernandez High School       0.808630
# Holden High School          0.962529
# Huang High School           0.813164
# Johnson High School         0.812224
# Pena High School            0.959459
# Rodriguez High School       0.802201
# Shelton High School         0.958546
# Thomas High School          0.973089
# Wilson High School          0.965396
# Wright High School          0.966111

# %%
# Calculate the overall passing rate (average of the math and reading passing rate)
passingrate = pd.merge(passingratem, passingrater, how="left", on=[ "school_name"])
passingrate['avg_score'] = (passingrate['math_score'] + passingrate['reading_score'])/2
passingrate
# Out:
#                        math_score  reading_score  avg_score
# school_name
# Bailey High School       0.666801       0.819333   0.743067
# Cabrera High School      0.941335       0.970398   0.955867
# Figueroa High School     0.659885       0.807392   0.733639
# Ford High School         0.683096       0.792990   0.738043
# Griffin High School      0.933924       0.971390   0.952657
# Hernandez High School    0.667530       0.808630   0.738080
# Holden High School       0.925059       0.962529   0.943794
# Huang High School        0.656839       0.813164   0.735002
# Johnson High School      0.660576       0.812224   0.736400
# Pena High School         0.945946       0.959459   0.952703
# Rodriguez High School    0.663666       0.802201   0.732933
# Shelton High School      0.938671       0.958546   0.948609
# Thomas High School       0.932722       0.973089   0.952905
# Wilson High School       0.938677       0.965396   0.952037
# Wright High School       0.933333       0.966111   0.949722

# %%
#  Sort and display the top five schools in overall passing rate
passingrate.sort_values('avg_score', ascending=False).head(5)
# Out:
#                      math_score  reading_score  avg_score
# school_name
# Cabrera High School    0.941335       0.970398   0.955867
# Thomas High School     0.932722       0.973089   0.952905
# Pena High School       0.945946       0.959459   0.952703
# Griffin High School    0.933924       0.971390   0.952657
# Wilson High School     0.938677       0.965396   0.952037

# %% [markdown]
# ### Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
#  Sort and display the worst five schools in overall passing rate
passingrate.sort_values('avg_score', ascending=False).tail(5)
# Out:
#                        math_score  reading_score  avg_score
# school_name
# Ford High School         0.683096       0.792990   0.738043
# Johnson High School      0.660576       0.812224   0.736400
# Huang High School        0.656839       0.813164   0.735002
# Figueroa High School     0.659885       0.807392   0.733639
# Rodriguez High School    0.663666       0.802201   0.732933

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Calculate the average math score for 9th grade in each school
by_grade = school_data_complete.loc[:,['school_name', 'math_score', 'grade']]
mscores = by_grade.groupby([ 'grade'])
nine = mscores.get_group('9th')
nine = nine.groupby('school_name').mean()
nine = nine.rename(columns={'math_score': 'math_score_9th'})
nine
# Out:
# /var/folders/lh/wqcyxpds3bnbkpsrdrggvkqh0000gn/T/ipykernel_37581/2641529868.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   nine = nine.groupby('school_name').mean()
#                        math_score_9th
# school_name
# Bailey High School          77.083676
# Cabrera High School         83.094697
# Figueroa High School        76.403037
# Ford High School            77.361345
# Griffin High School         82.044010
# Hernandez High School       77.438495
# Holden High School          83.787402
# Huang High School           77.027251
# Johnson High School         77.187857
# Pena High School            83.625455
# Rodriguez High School       76.859966
# Shelton High School         83.420755
# Thomas High School          83.590022
# Wilson High School          83.085578
# Wright High School          83.264706

# %%
# Calculate the average math score for 10th grade in each school
ten = mscores.get_group('10th')
ten = ten.groupby('school_name').mean()
ten = ten.rename(columns={'math_score': 'math_score_10th'})
ten
# Out:
# /var/folders/lh/wqcyxpds3bnbkpsrdrggvkqh0000gn/T/ipykernel_37581/1853486076.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ten = ten.groupby('school_name').mean()
#                        math_score_10th
# school_name
# Bailey High School           76.996772
# Cabrera High School          83.154506
# Figueroa High School         76.539974
# Ford High School             77.672316
# Griffin High School          84.229064
# Hernandez High School        77.337408
# Holden High School           83.429825
# Huang High School            75.908735
# Johnson High School          76.691117
# Pena High School             83.372000
# Rodriguez High School        76.612500
# Shelton High School          82.917411
# Thomas High School           83.087886
# Wilson High School           83.724422
# Wright High School           84.010288

# %%
# Calculate the average math score for 11th grade in each school
eleven = mscores.get_group('11th')
eleven = eleven.groupby('school_name').mean()
eleven = eleven.rename(columns={'math_score': 'math_score_11th'})

eleven
# Out:
# /var/folders/lh/wqcyxpds3bnbkpsrdrggvkqh0000gn/T/ipykernel_37581/2395356994.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   eleven = eleven.groupby('school_name').mean()
#                        math_score_11th
# school_name
# Bailey High School           77.515588
# Cabrera High School          82.765560
# Figueroa High School         76.884344
# Ford High School             76.918058
# Griffin High School          83.842105
# Hernandez High School        77.136029
# Holden High School           85.000000
# Huang High School            76.446602
# Johnson High School          77.491653
# Pena High School             84.328125
# Rodriguez High School        76.395626
# Shelton High School          83.383495
# Thomas High School           83.498795
# Wilson High School           83.195326
# Wright High School           83.836782

# %%
# Calculate the average math score for 12th grade in each school
twelve = mscores.get_group('12th')
twelve = twelve.groupby('school_name').mean()
twelve = twelve.rename(columns={'math_score': 'math_score_12th'})

twelve
# Out:
# /var/folders/lh/wqcyxpds3bnbkpsrdrggvkqh0000gn/T/ipykernel_37581/3987693376.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   twelve = twelve.groupby('school_name').mean()
#                        math_score_12th
# school_name
# Bailey High School           76.492218
# Cabrera High School          83.277487
# Figueroa High School         77.151369
# Ford High School             76.179963
# Griffin High School          83.356164
# Hernandez High School        77.186567
# Holden High School           82.855422
# Huang High School            77.225641
# Johnson High School          76.863248
# Pena High School             84.121547
# Rodriguez High School        77.690748
# Shelton High School          83.778976
# Thomas High School           83.497041
# Wilson High School           83.035794
# Wright High School           83.644986

# %%
# Create table that lists the average math score for each school of each grade level.
gradesm = pd.merge(pd.merge(pd.merge(nine, ten, on= "school_name"), eleven, on= "school_name"), twelve, on= "school_name")
gradesm
# Out:
#                        math_score_9th  math_score_10th  math_score_11th  \
# school_name
# Bailey High School          77.083676        76.996772        77.515588
# Cabrera High School         83.094697        83.154506        82.765560
# Figueroa High School        76.403037        76.539974        76.884344
# Ford High School            77.361345        77.672316        76.918058
# Griffin High School         82.044010        84.229064        83.842105
# Hernandez High School       77.438495        77.337408        77.136029
# Holden High School          83.787402        83.429825        85.000000
# Huang High School           77.027251        75.908735        76.446602
# Johnson High School         77.187857        76.691117        77.491653
# Pena High School            83.625455        83.372000        84.328125
# Rodriguez High School       76.859966        76.612500        76.395626
# Shelton High School         83.420755        82.917411        83.383495
# Thomas High School          83.590022        83.087886        83.498795
# Wilson High School          83.085578        83.724422        83.195326
# Wright High School          83.264706        84.010288        83.836782
#
#                        math_score_12th
# school_name
# Bailey High School           76.492218
# Cabrera High School          83.277487
# Figueroa High School         77.151369
# Ford High School             76.179963
# Griffin High School          83.356164
# Hernandez High School        77.186567
# Holden High School           82.855422
# Huang High School            77.225641
# Johnson High School          76.863248
# Pena High School             84.121547
# Rodriguez High School        77.690748
# Shelton High School          83.778976
# Thomas High School           83.497041
# Wilson High School           83.035794
# Wright High School           83.644986

# %% [markdown]
# ### Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Calculate the average reading score for 9th grade in each school
by_grade = school_data_complete.loc[:,['school_name', 'reading_score', 'grade']]
rscores = by_grade.groupby([ 'grade'])
nine = rscores.get_group('9th')
nine = nine.groupby('school_name').mean()
nine = nine.rename(columns={'reading_score': 'reading_score_9th'})
nine
# Out:
# /var/folders/lh/wqcyxpds3bnbkpsrdrggvkqh0000gn/T/ipykernel_37581/3071361860.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   nine = nine.groupby('school_name').mean()
#                        reading_score_9th
# school_name
# Bailey High School             81.303155
# Cabrera High School            83.676136
# Figueroa High School           81.198598
# Ford High School               80.632653
# Griffin High School            83.369193
# Hernandez High School          80.866860
# Holden High School             83.677165
# Huang High School              81.290284
# Johnson High School            81.260714
# Pena High School               83.807273
# Rodriguez High School          80.993127
# Shelton High School            84.122642
# Thomas High School             83.728850
# Wilson High School             83.939778
# Wright High School             83.833333

# %%
# Calculate the average reading score for 10th grade in each school
ten = rscores.get_group('10th')
ten = ten.groupby('school_name').mean()
ten = ten.rename(columns={'reading_score': 'reading_score_10th'})
ten
# Out:
# /var/folders/lh/wqcyxpds3bnbkpsrdrggvkqh0000gn/T/ipykernel_37581/595655512.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ten = ten.groupby('school_name').mean()
#                        reading_score_10th
# school_name
# Bailey High School              80.907183
# Cabrera High School             84.253219
# Figueroa High School            81.408912
# Ford High School                81.262712
# Griffin High School             83.706897
# Hernandez High School           80.660147
# Holden High School              83.324561
# Huang High School               81.512386
# Johnson High School             80.773431
# Pena High School                83.612000
# Rodriguez High School           80.629808
# Shelton High School             83.441964
# Thomas High School              84.254157
# Wilson High School              84.021452
# Wright High School              83.812757

# %%
# Calculate the average reading score for 11th grade in each school
eleven = rscores.get_group('11th')
eleven = eleven.groupby('school_name').mean()
eleven = eleven.rename(columns={'reading_score': 'reading_score_11th'})
eleven
# Out:
# /var/folders/lh/wqcyxpds3bnbkpsrdrggvkqh0000gn/T/ipykernel_37581/2078822123.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   eleven = eleven.groupby('school_name').mean()
#                        reading_score_11th
# school_name
# Bailey High School              80.945643
# Cabrera High School             83.788382
# Figueroa High School            80.640339
# Ford High School                80.403642
# Griffin High School             84.288089
# Hernandez High School           81.396140
# Holden High School              83.815534
# Huang High School               81.417476
# Johnson High School             80.616027
# Pena High School                84.335938
# Rodriguez High School           80.864811
# Shelton High School             84.373786
# Thomas High School              83.585542
# Wilson High School              83.764608
# Wright High School              84.156322

# %%
# Calculate the average reading score for 12th grade in each school
twelve = mscores.get_group('12th')
twelve = twelve.groupby('school_name').mean()
twelve = twelve.rename(columns={'reading_score': 'reading_score_12th'})
twelve
# Out:
# /var/folders/lh/wqcyxpds3bnbkpsrdrggvkqh0000gn/T/ipykernel_37581/293187271.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   twelve = twelve.groupby('school_name').mean()
#                        math_score
# school_name
# Bailey High School      76.492218
# Cabrera High School     83.277487
# Figueroa High School    77.151369
# Ford High School        76.179963
# Griffin High School     83.356164
# Hernandez High School   77.186567
# Holden High School      82.855422
# Huang High School       77.225641
# Johnson High School     76.863248
# Pena High School        84.121547
# Rodriguez High School   77.690748
# Shelton High School     83.778976
# Thomas High School      83.497041
# Wilson High School      83.035794
# Wright High School      83.644986

# %%
# Create table that lists the average reading score for each school of each grade level.
gradesm = pd.merge(pd.merge(pd.merge(nine, ten, on= "school_name"), eleven, on= "school_name"), twelve, on= "school_name")
gradesm
# Out:
#                        reading_score_9th  reading_score_10th  \
# school_name
# Bailey High School             81.303155           80.907183
# Cabrera High School            83.676136           84.253219
# Figueroa High School           81.198598           81.408912
# Ford High School               80.632653           81.262712
# Griffin High School            83.369193           83.706897
# Hernandez High School          80.866860           80.660147
# Holden High School             83.677165           83.324561
# Huang High School              81.290284           81.512386
# Johnson High School            81.260714           80.773431
# Pena High School               83.807273           83.612000
# Rodriguez High School          80.993127           80.629808
# Shelton High School            84.122642           83.441964
# Thomas High School             83.728850           84.254157
# Wilson High School             83.939778           84.021452
# Wright High School             83.833333           83.812757
#
#                        reading_score_11th  math_score
# school_name
# Bailey High School              80.945643   76.492218
# Cabrera High School             83.788382   83.277487
# Figueroa High School            80.640339   77.151369
# Ford High School                80.403642   76.179963
# Griffin High School             84.288089   83.356164
# Hernandez High School           81.396140   77.186567
# Holden High School              83.815534   82.855422
# Huang High School               81.417476   77.225641
# Johnson High School             80.616027   76.863248
# Pena High School                84.335938   84.121547
# Rodriguez High School           80.864811   77.690748
# Shelton High School             84.373786   83.778976
# Thomas High School              83.585542   83.497041
# Wilson High School              83.764608   83.035794
# Wright High School              84.156322   83.644986

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
# Create a new column to show budget per student in each row
school_data_complete['budget_per_student'] = school_data_complete['budget'] / school_data_complete['size']
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
#        per student budget  budget_per_student
# 0                   655.0               655.0
# 1                   655.0               655.0
# 2                   655.0               655.0
# 3                   655.0               655.0
# 4                   655.0               655.0
# ...                   ...                 ...
# 39165               638.0               638.0
# 39166               638.0               638.0
# 39167               638.0               638.0
# 39168               638.0               638.0
# 39169               638.0               638.0
#
# [39170 rows x 13 columns]

# %%
# Create a new column to define the spending ranges per student
conditions = [
    (school_data_complete['budget_per_student'] <= 585),
    (school_data_complete['budget_per_student'] > 585) & (school_data_complete['budget_per_student'] <= 615),
    (school_data_complete['budget_per_student'] > 615) & (school_data_complete['budget_per_student'] <= 645),
    (school_data_complete['budget_per_student'] >645 )]
values = ["<$585", "$585-615", "$615-645", "$645-675"]
school_data_complete['spending'] = np.select(conditions, values)   
                     
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
#        per student budget  budget_per_student  spending
# 0                   655.0               655.0  $645-675
# 1                   655.0               655.0  $645-675
# 2                   655.0               655.0  $645-675
# 3                   655.0               655.0  $645-675
# 4                   655.0               655.0  $645-675
# ...                   ...                 ...       ...
# 39165               638.0               638.0  $615-645
# 39166               638.0               638.0  $615-645
# 39167               638.0               638.0  $615-645
# 39168               638.0               638.0  $615-645
# 39169               638.0               638.0  $615-645
#
# [39170 rows x 14 columns]

# %%
# Calculate the average math score within each spending range
spendingScore = school_data_complete.loc[:,['spending', 'math_score']]
sscores = spendingScore.groupby([ 'spending']).mean()
sscores
# Out:
#           math_score
# spending
# $585-615   83.529196
# $615-645   78.061635
# $645-675   77.049297
# <$585      83.363065

# %%
# Calculate the percentage passing rate for math in each spending range
countpassms = spendingScore[spendingScore['math_score'] >= 70]
countpassms = countpassms.groupby('spending').count()
countspending = spendingScore.groupby('spending').count()
spendingPassRatem = countpassms / countspending
spendingPassRatem = spendingPassRatem.rename(columns={'math_score': 'math_passing_rate'})
spendingPassRatem
# Out:
#           math_passing_rate
# spending
# $585-615           0.941241
# $615-645           0.714004
# $645-675           0.662308
# <$585              0.937029

# %%
# Calculate the percentage passing rate for reading in each spending range
spendingScorer = school_data_complete.loc[:,['spending', 'reading_score']]
countpassrs = spendingScorer[spendingScorer['reading_score'] >= 70]
countpassrs = countpassrs.groupby('spending').count()
countspending = spendingScorer.groupby('spending').count()
spendingPassRater = countpassrs / countspending
spendingPassRater = spendingPassRater.rename(columns={'reading_score': 'read_passing_rate'})
spendingPassRater
# Out:
#           read_passing_rate
# spending
# $585-615           0.958869
# $615-645           0.836148
# $645-675           0.811094
# <$585              0.966866

# %%
# Calculate the percentage overall passing rate in each spending range
spendpassing = spendingPassRater.merge(spendingPassRatem, on= "spending")
spendpassing['overall_pass_rate'] = (spendpassing['read_passing_rate'] + spendpassing['math_passing_rate'])/2
spendpassing
# Out:
#           read_passing_rate  math_passing_rate  overall_pass_rate
# spending
# $585-615           0.958869           0.941241           0.950055
# $615-645           0.836148           0.714004           0.775076
# $645-675           0.811094           0.662308           0.736701
# <$585              0.966866           0.937029           0.951947

# %% [markdown]
# ### Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
# Create a new column for the bin groups
conditions = [
    (school_data_complete['size'] <= 1000),
    (school_data_complete['size'] > 1000) & (school_data_complete['size'] <= 2000),
    (school_data_complete['size'] > 2000) & (school_data_complete['size'] <= 5000)]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
school_data_complete['sizes'] = np.select(conditions, group_names)   
                     
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
#        per student budget  budget_per_student  spending               sizes
# 0                   655.0               655.0  $645-675   Large (2000-5000)
# 1                   655.0               655.0  $645-675   Large (2000-5000)
# 2                   655.0               655.0  $645-675   Large (2000-5000)
# 3                   655.0               655.0  $645-675   Large (2000-5000)
# 4                   655.0               655.0  $645-675   Large (2000-5000)
# ...                   ...                 ...       ...                 ...
# 39165               638.0               638.0  $615-645  Medium (1000-2000)
# 39166               638.0               638.0  $615-645  Medium (1000-2000)
# 39167               638.0               638.0  $615-645  Medium (1000-2000)
# 39168               638.0               638.0  $615-645  Medium (1000-2000)
# 39169               638.0               638.0  $615-645  Medium (1000-2000)
#
# [39170 rows x 15 columns]

# %% [markdown]
# Look for the total count of test scores that pass 70% or higher

# %%
# math_pass_size
pass_sizem = school_data_complete.loc[:,['sizes', 'math_score']]
countsizem = pass_sizem[pass_sizem['math_score'] >= 70]
countsizem = countsizem.groupby('sizes').count()
countsize= pass_sizem.groupby('sizes').count()
mpassRateSize = countsizem/countsize
mpassRateSize
# Out:
#                     math_score
# sizes
# Large (2000-5000)     0.686524
# Medium (1000-2000)    0.936165
# Small (<1000)         0.939525

# %%
# read_pass_size
pass_sizer = school_data_complete.loc[:,['sizes', 'reading_score']]
countsizer = pass_sizer[pass_sizer['reading_score'] >= 70]
countsizer = countsizer.groupby('sizes').count()
countsize= pass_sizer.groupby('sizes').count()
rpassRateSize = countsizer/countsize
rpassRateSize
# Out:
#                     reading_score
# sizes
# Large (2000-5000)        0.821252
# Medium (1000-2000)       0.967731
# Small (<1000)            0.960403

# %%
# Calculate the overall passing rate for different school size
sizepassing = rpassRateSize.merge(mpassRateSize, on= "sizes")
sizepassing['overall_pass_rate'] = (sizepassing['reading_score'] + sizepassing['math_score'])/2
sizepassing
# Out:
#                     reading_score  math_score  overall_pass_rate
# sizes
# Large (2000-5000)        0.821252    0.686524           0.753888
# Medium (1000-2000)       0.967731    0.936165           0.951948
# Small (<1000)            0.960403    0.939525           0.949964

# %% [markdown]
# ### Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
# Create bins and groups, school type {'Charter', 'District'}
school_type_bins = [charter, district]
group_names = ["charter", "district"]

# %% [markdown]
# Find counts of the passing 70 or higher score for the both test

# %%
# math pass size
pass_typem = school_data_complete.loc[:,['type', 'math_score']]
counttypem = pass_typem[pass_sizem['math_score'] >= 70]
counttypem = counttypem.groupby('type').count()
counttype= pass_typem.groupby('type').count()
mpassRatetype = counttypem/counttype
mpassRatetype
# Out:
#           math_score
# type
# Charter     0.937018
# District    0.665184

# %%
# reading pass size
pass_typer = school_data_complete.loc[:,['type', 'reading_score']]
counttyper = pass_typer[pass_sizer['reading_score'] >= 70]
counttyper = counttyper.groupby('type').count()
counttype= pass_typer.groupby('type').count()
rpassRatetype = counttyper/counttype
rpassRatetype
# Out:
#           reading_score
# type
# Charter        0.966459
# District       0.809052

# %%
# Calculate the overall passing rate
typepassing = rpassRatetype.merge(mpassRatetype, on= "type")
typepassing['overall_pass_rate'] = (typepassing['reading_score'] + typepassing['math_score'])/2
typepassing
# Out:
#           reading_score  math_score  overall_pass_rate
# type
# Charter        0.966459    0.937018           0.951739
# District       0.809052    0.665184           0.737118
